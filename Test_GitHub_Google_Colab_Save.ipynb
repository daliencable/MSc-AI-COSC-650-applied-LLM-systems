# %% [markdown]
# <a href="https://colab.research.google.com/github/daliencable/MSc-AI-COSC-650-applied-LLM-systems-/blob/main/Test_GitHub_Google_Colab_Save.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# testing saving a copy from Colab to my GitHub Repo
